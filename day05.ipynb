# %% [markdown]
# <a href="https://colab.research.google.com/github/alimdrinku/50-days-of-python-for-beginners-/blob/main/day05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lets assin variables

x= 10
y=5
z=2

# addition, sub,mutl etc

x+y
# Out:
# 15

# %%
x/y
# Out:
# 2.0

# %%
x*y
# Out:
# 50

# %%
x//y
# Out:
# 2

# %%
# identity oparetors

x=10
y=10
x is y
# Out:
# True

# %%
x==y   #comparism
# Out:
# True

# %%
a = 10010
b=10010

a is b
# Out:
# False

# %%
id(a)
# Out:
# 136120726690352

# %%
id(b)
# Out:
# 136120726694672

# %%
a is not b
# Out:
# True

# %%
#membership operator
list1=[1,2,3,4,5,6,7,8]

1 in list1
# Out:
# True

# %%
9 not in list1
# Out:
# True

# %%
s1 = {1,2,3,4,5}
2  in s1
# Out:
# True

# %%
str1='python is a programming language'
'python'in str1
# Out:
# True

# %%
'Python' in str1
# Out:
# False

# %%
#lets learn bit operators
x=1010 #10
y=101 #5

x=10
y=5
print(x|y)
# Out:
# 15

# %%
x&y
# Out:
# 0

# %%
x=10
y=5
x>y
# Out:
# True

# %%
not(x<y)&(x==y)
# Out:
# True

# %% [markdown]
# <a href="https://colab.research.google.com/github/alimdrinku/50-days-of-python-for-beginners-/blob/main/day06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# today we will learn about python conditions
# IF ELSE
x = 20
y = 30
if y>x:
  print("y is greater than x")
elif x==y:
  print("x and y are equal")
else:
    print("x is greater than y")
# Out:
# y is greater than x

# %%
# simple if else statement
str1='lets learn python'
if 'learn' in str1:
  print('yes')
else:
  print('no')
# Out:
# yes

# %%
# if else
num1=1011
num2=1011
if num1>num2:
  print('num1 is greater than num2')
elif num1==num2:
  print('num1 is equal to num2')
else:
  print('num1 is less than num2')
# Out:
# num1 is equal to num2

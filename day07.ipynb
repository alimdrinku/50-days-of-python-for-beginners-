# %% [markdown]
# <a href="https://colab.research.google.com/github/alimdrinku/50-days-of-python-for-beginners-/blob/main/day07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# if else statement

x=20
y=40

if x>y:
    print("x is greater than y")
else:
    print("y is greater than x")
# Out:
# y is greater than x

# %%
# we will take a user input
x=int(input("enter the value of x:"))
y=int(input("enter the value of y:"))

if x>y:
    print("x is greater than y")
else:
    print("y is greater than x")
# Out:
# enter the value of x:50
# enter the value of y:60
# y is greater than x

# %%
#finding even odd num
num=int(input("enter the number:"))
if num%2==0:
    print("number is even")
else:
    print("number is odd")
# Out:
# enter the number:25
# number is odd

# %%
# electricity bill problem
# first 50 unit is 3.5 per unit , 50-75 is 4.5 per unit ,
#after 75 is 5 per unit
bill=0
unit=float(input("enter the number of units:"))

if unit<=50:
    bill=unit*3.5
    print('your bill is : ', bill)
elif unit<=75:
    bill=50*3.5+(unit-50)*4.5
    print('your bill is : ', bill)
elif unit>75:
    bill=50*3.5+25*4.5+(unit-75)*5
    print('your bill is : ', bill)
# Out:
# enter the number of units:55.6
# your bill is :  200.20000000000002

# %%
# so heres some simple exmple of if elif and else statement
